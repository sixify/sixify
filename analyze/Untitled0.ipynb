# %%
import pandas

inputDataframe = pandas.read_csv("./input_feeds/sixify_bitstamp_btcusd.csv")

binningTime = 5*60 # 5 min

numberOfBins = (max(inputDataframe.date)- min(inputDataframe.date))/binningTime 

amounts =  inputDataframe.amount

Binned data[:(data.size // numberOfBins) * numberOfBins].reshape(-1, width).mean(axis=1)

# %%
import numpy as np

width=3
data = np.array(amounts)

result = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

print result
# Out:
# [ 0.35285019  1.00626327  0.04713239  0.36863967  0.09554     3.30274042
#   0.28337267  0.50806756  0.9458722   3.49424551  1.16219661  0.08807817
#   0.88993622  1.65120752  1.98193776  3.07973333  1.39242206  0.34503667
#   2.00577935  3.82443634  5.07789515  0.0792      0.52933333  0.69131813
#   0.397       0.26466667  0.397       0.397       0.397       0.31057751
#   0.29345698  0.35433291  0.41845094  0.14344148  1.67610758  0.8806654
#   0.05048361  0.45840807  0.55072004  0.89060642  2.83116931  2.45569667
#   4.16780069  0.14126518  0.38535046  0.32971667  0.95061667  0.9933      0.073
#   0.04666667  0.50646     3.21588769  0.36390553  2.92133645  0.01879428
#   1.50572323  0.82054774  2.          1.26532     1.1227922   2.
#   2.02202685  2.          0.20473933  1.64566667  0.67344333  0.65863333
#   0.25653333  0.52741745  0.68        0.02        0.71331888  0.37927961
#   0.51333333  0.67939855  0.18008313  0.21816085  0.23852503]

# %%
print data
# Out:
# [  6.14687190e-01   1.69863380e-01   2.74000000e-01   6.26580830e-01
#    4.60606150e-01   1.93160282e+00   3.41998900e-02   3.41972900e-02
#    7.30000000e-02   4.24200000e-01   1.83000000e-01   4.98719010e-01
#    5.70099900e-02   2.01010000e-01   2.86000000e-02   1.75058600e-01
#    6.02641449e+00   3.70674818e+00   5.00000000e-01   6.00000000e-02
#    2.90118020e-01   9.50101000e-02   2.95042060e-01   1.13415052e+00
#    6.63660000e-04   8.36952950e-01   2.00000000e+00   7.30000000e-01
#    1.92000000e-02   9.73353652e+00   9.25688020e-01   2.48700000e+00
#    7.39018200e-02   2.38254600e-02   1.17239340e-01   1.23169700e-01
#    2.86477000e-01   4.10266190e-01   1.97306546e+00   2.69345400e-02
#    9.25688020e-01   4.00100000e+00   1.49586773e+00   3.99946924e+00
#    4.50476300e-01   5.00000000e+00   4.22000000e+00   1.92000000e-02
#    3.84105844e+00   1.34868070e-01   2.01339680e-01   7.26110000e-01
#    5.00000000e-02   2.59000000e-01   5.13784805e+00   8.50810000e-01
# ...
